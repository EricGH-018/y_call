# %% [markdown]
# # Example of usage for **y_call** algorithm: making Y-haplogroup calls #

# %% [markdown]
# ***

# %% [markdown]
# ## Description ##

# %% [markdown]
# This Jupter Botebook contains an explained and guided usage of **y_call**, a software designed to make Y-haplogroup calls both on modern and aDNA data. Here, absolute paths in the local clsuter have been considered for input data, but these can be specified by the user at any other location.

# %% [markdown]
# ***

# %% [markdown]
# ## Installation ##

# %% [markdown]
# Import modules:

# %%
# Import modules
import numpy as np
import os  # for saving to folder
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.rcdefaults() # default settings to avoid warnings related to font.
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout

import socket
import os as os
import sys as sys
import multiprocessing as mp
from pysam import AlignmentFile
import argparse

import requests # to look for weblinks. 
from bs4 import BeautifulSoup # to transform into table information in a database.
import urllib # also to retrieve weblinks.
import time
from liftover import get_lifter # to convert positions from hg38 to hg19 (used to align reads).
import seaborn as sns # for visualization.
import re # to work with regular expressions.
import pathlib
from pathlib import Path

# %% [markdown]
# Import package:

# %%
sys.path.append("..")

# Import package from current directory.
from pulldown import y_call

os.chdir("/mnt/archgen/users/eric_garcia/Jupyter_Vignette/")

# %% [markdown]
# ***

# %% [markdown]
# ## Understanding necessary input files ##

# %% [markdown]
# This section contains a brief explanation on the input files necessary to run the package. Other arguments provided to it stand for filtering options, as well as the creation of a network connecting haplogroups and samples.

# %% [markdown]
# > **bam_list**: relative or abosulte (preferibly) path to a .tsv file containing a list of the routes to different .bam files. This file contains 3 columns in total:
# > 1. **iid**: the individual ID for every sample.
# > 2. **bam**: absolute or relative path to each .bam file.
# > 3. **sex**: chromosomal sex for every sample. f = female, m = mascle.

# %%
bam_list = "/mnt/archgen/users/hringbauer/git/EPIDEMIC/output/tables/autoeager_seqfull_anno.tsv"

# Show the content of the file
table1 = pd.read_csv(bam_list, sep="\t", usecols=["iid", "bam", "sex"])
table1.head()
# Out:
#       iid                                                bam sex
# 0  PTN271  /mnt/archgen/Autorun_eager/eager_outputs/SG/PT...   f
# 1  PTN225  /mnt/archgen/Autorun_eager/eager_outputs/SG/PT...   f
# 2  PTN209  /mnt/archgen/Autorun_eager/eager_outputs/SG/PT...   m
# 3  PTN287  /mnt/archgen/Autorun_eager/eager_outputs/SG/PT...   f
# 4  KKH019  /mnt/archgen/Autorun_eager/eager_outputs/SG/KK...   m

# %% [markdown]
# > **path_snps**: relative or abosulte (preferibly) path to a .csv file containing a list of the SNPs considered in the analysis.
# > 1. **Coordinates**: genome coordinates in chrY (hg38 version in the example).
# > 2. **ANC**: ancestral allele.
# > 3. **DER**: derived allele.
# > 4. **SNP-ID**: name of the SNP at that location.

# %%
path_snps = "/home/eric_garcia_hoyos/y_call/data/input/YBrowse_snps_hg38-runtime.csv"

# Show the content of the file
table2 = pd.read_csv(path_snps, dtype=object, sep=" ", header=None, names = ["Coordinates", "ANC", "DER", "SNP-ID"])
table2.head(10)
# Out:
#   Coordinates ANC DER     SNP-ID
# 0    10000002   A   G   FTD27388
# 1    10000003   G   T    MF63801
# 2    10000017   T   A   FTC40137
# 3    10000024   C   T    TY15024
# 4    10000025   A   C    BY81325
# 5    10000032   C   T    TY15023
# 6    10000044   T   C   MF159896
# 7    10000054   G   C  FGCLR1744
# 8    10000056   A   G   FT342891
# 9    10000062   A   C    Y138007

# %% [markdown]
# > **tree**: relative or abosulte (preferibly) path to a .csv file containing child - parent pairs of haplogroups. Although not named in original file, there exist two columns:
# > 1. **Child**: every haplogroup as a descendant of another haplogroup.
# > 2. **Parent**: parental node of the **Child** haplogroup.
# >
# > This file corresponds to the Y-haplogroup tree where samples are placed.

# %%
tree = "/home/eric_garcia_hoyos/y_call/data/input/OYchpar.csv"

# Show the content of the file
table3 = pd.read_csv(tree, header=None, names = ["Child", "Parent"])
table3.head(5)
# Out:
#       Child        Parent
# 0  A-A12220  A00-FGC26001
# 1  A-A12222    A-FGC28278
# 2  A-A20843    A-FT185719
# 3   A-A4995      A-YP2683
# 4  A-ALK773      A-ALK828

# %%
# If Child selected for a specific haplogroup (R-M343):
table3[table3["Child"]=="R-M343"]
# Out:
#          Child        Parent
# 105132  R-M343  R-PAGES00029

# %%
# If Parent selected for a specific haplogroup (R-M343):
table3[table3["Parent"]=="R-M343"]
# Out:
#                Child  Parent
# 67392      R-BY14355  R-M343
# 114630  R-YSC0000022  R-M343

# %% [markdown]
# > **translation**: relative or abosulte (preferibly) path to a .csv file containing synonymous names for haplogroup to avoid inconsistencies between databases. Although not named in the original file, there exist two columns:
# > 1. **Large**: nomenclature based on the alphabetical order, usually referred as large nomeclature (since names become larger).
# > 2. **Short**: SNP-based nomenclature, where every haplogroup is named after the defining SNP of the branch.

# %%
translation = "../data/input/YF-translations.csv"

# Show the content of the file
table4 = pd.read_csv(translation, header=None, names = ["Large", "Short"])[20:30]
table4
# Out:
#     Large     Short
# 20  A3b2b    A-M118
# 21      B     B-M60
# 22     B1    B-M146
# 23    B2a    B-M150
# 24   B2a1    B-M109
# 25   B2a2  B-M108.1
# 26  B2a2a     B-M43
# 27    B2b    B-M112
# 28   B2b1      B-P6
# 29   B2b2    B-M115

# %% [markdown]
# > **mm**: relative or abosulte (preferibly) path to a .tsv file containing the number of samples where a SNP had an ancestral allele. Although not named in the original file, there exist two columns:
# > 1. **SNP-ID**: name of the SNP.
# > 2. **count**: total number of samples with the ancestral allele.

# %%
mm = "../data/input/mm_v3.tsv"

# Show the content of the file
table5 = pd.read_csv(mm, sep="\t")
table5.head()
# Out:
#         SNP-ID  count
# 0        Z9315    115
# 1     BY184462    103
# 2        V3167    101
# 3     FGC27824     89
# 4  V6478,Z9327     87

# %% [markdown]
# > **branches**: relative or abosulte (preferibly) path to a .csv file containing the name of each haplogroup (first value) and all SNPs contained inside that haplogroup (rest of values).

# %%
branches = "../data/input/OYhaps.csv"

# Show the content of the file
with open(branches, "r") as f:
    for line in f.readlines()[4:5]: # read a single line of the document.
        items = line.strip().split() # because every line is: X-XXXX X123 X542 XG56*
        print(f"\nThis is the content of a whole line in the file: {items}")
        if not items:
            continue

        hap = items[0] # only the first value (the haplogroup).
        snps = items[1:] # the rest of values (the SNPs).
        print(f"\n--> Where the haplogroup is: {hap}\n\n--> And the set of SNPs contained inside of it is: {snps}")
# Out:
# This is the content of a whole line in the file: ['A-A4995', 'A4995', 'A4996', 'A4998', 'FTB31618']
#
# --> Where the haplogroup is: A-A4995
#
# --> And the set of SNPs contained inside of it is: ['A4995', 'A4996', 'A4998', 'FTB31618']

# %% [markdown]
# ***

# %% [markdown]
# ## Running **y_call** on a single sample ##

# %% [markdown]
# So, now that we have all our necessary input files loaded, we can run the program. To do so, we provide a few more parameters so that the analysis considers some aspects:
# > **initial**: index for first the sample to analyse.
# >
# > **final**: index for the last sample to analyse.
# >
# > **base_qual**: minimum base quality considered for the call.
# >
# > **map_qual**: minimum mapping quality for the call.
# >
# > **reference_genome**: version of the human genome used in for the markers coordinates.
# >
# > **create_network**: desired network connecting haplogroup and placing samples in it.
# >
# > **width**: width size for the network.
# >
# > **height**: height size for the network.
# >
# > **transitions**: filtering for transitions.
# >
# > **ex_limit**: minimum number of samples supporting an ancestral allele for one of the SNPs in mm.

# %%
# Run function for the software: y_call.
y_call(bam_list=bam_list, initial=2, final=3,
       base_qual=20, map_qual=25, path_snps=path_snps,
       reference_genome="hg38", create_network="N",
       width=20, height=30, transitions="Y",
       tree=tree, translation=translation, mm=mm,
       branches=branches, ex_limit=5)
# Out:
# Dataset for filtered markers already saved: ./data/output/all_snps.csv
# Corresponding .bed file in data/output/OY_snps.bed
#
# - Loaded a total of 1 male individuals. -
#
#
# - Summary coverage statistics for sample PTN227 -
# Average Coverage: 0.3754x
# #Sites covered: 834965 / 2878063
# #Derived Loci: 4376 / 834965 covered>0
#
# Saved data for pileup as data/output/markers/PTN227/snps_PTN227.tsv
# Saved data for pileup (considering only derived sites) as data/output/markers/PTN227/snps_der_PTN227.tsv
# Y-haplogroup simplified tree saved as data/output/trees/PTN227/tree_output_PTN227.txt
# Path to most derived haplogroup included in data/output/paths.txt
#
# Saved Y-haplogroup calls for 1 individuals as data/output/scores.csv.
#
# - Running analysis to know the total number of unique lineages in dataset -
#
#
# Total number of unique lineages in dataset: 1.

# %% [markdown]
# ***

# %% [markdown]
# ## Understanding the output ##

# %% [markdown]
# This section contains a brief explanation on the output files generated by the package. All this information is stored in an automatically created directory, found in ./data/output

# %% [markdown]
# > **./data/output/markers/iid/snps_iid.tsv**: this file contains information only for those SNPs covered in the analysis, including base count, as well as ancestral and derived states count.

# %%
data1 = pd.read_csv("data/output/markers/PTN227/snps_PTN227.tsv", sep="\t")
data1
# Out:
#         Unnamed: 0.1  Unnamed: 0    SNP-ID chrom       pos ref alt  \
# 0                  0        3011   TY95567     Y   2649650   A   G
# 1                  1        3012   Y662350     Y   2649654   T   C
# 2                  2        3013   C281242     Y   2649657   G   C
# 3                  6        3017  FTB18424     Y   2649665   T   A
# 4                  7        3018    Y29216     Y   2649666   A   G
# ...              ...         ...       ...   ...       ...  ..  ..
# 610740        899457     2878011  BY227657     Y  59033110   A   T
# 610741        899458     2878012   TY34949     Y  59033135   A   T
# 610742        899459     2878013  BY227607     Y  59033139   T   C
# 610743        899460     2878014   Y553748     Y  59033175   T   A
# 610744        899463     2878022  MF653453     Y  59033249   G   T
#
#        Y-haplogroup YFull translation  Level  A  C  G  T  ref#  alt#
# 0               NaN               NaN      0  1  0  0  0     1     0
# 1               NaN               NaN      0  0  0  0  1     1     0
# 2               NaN               NaN      0  0  0  1  0     1     0
# 3        J-FT226311               NaN     47  0  0  0  1     1     0
# 4               NaN               NaN      0  1  0  0  0     1     0
# ...             ...               ...    ... .. .. .. ..   ...   ...
# 610740          NaN               NaN      0  1  0  0  3     1     3
# 610741          NaN               NaN      0  4  0  0  0     4     0
# 610742          NaN               NaN      0  0  2  0  2     2     2
# 610743          NaN               NaN      0  0  0  0  1     1     0
# 610744          NaN               NaN      0  0  0  3  0     3     0
#
# [610745 rows x 16 columns]

# %% [markdown]
# > **./data/output/markers/iid/snps_der_iid.tsv**: this file follows the same structure as the previous, with the only difference that it contains information only for SNPs considered as derived (alternative allele count higher than ancestral count).

# %%
data2 = pd.read_csv("data/output/markers/PTN227/snps_der_PTN227.tsv", sep="\t")
data2
# Out:
#       Unnamed: 0.1  Unnamed: 0         SNP-ID chrom       pos ref alt  \
# 0                0      494603         A10341     Y   6595308   G   A
# 1                1     2742066  A10581,ZS5144     Y  24007924   C   T
# 2                2     1098949    A10970,E169     Y  13687378   A   T
# 3                3      621422         A11664     Y   7332742   C   T
# 4                4      862290         A11796     Y   8670352   G   A
# ...            ...         ...            ...   ...       ...  ..  ..
# 4371          4371      647106         ZS5245     Y   7523232   G   A
# 4372          4372     1631652         ZS6246     Y  16630436   G   A
# 4373          4373      728790          ZS645     Y   7970540   C   T
# 4374          4374     1060913         ZS7939     Y  13450812   A   G
# 4375          4375     2064913         ZS9573     Y  19069699   C   T
#
#      Y-haplogroup YFull translation  Level  A  C  G   T  ref#  alt#
# 0             NaN               NaN      0  1  0  0   0     0     1
# 1        R-A10557               NaN     45  0  0  0   1     0     1
# 2             NaN               NaN      0  1  0  0  25     1    25
# 3             NaN               NaN      0  0  0  0   2     0     2
# 4             NaN               NaN      0  1  0  0   0     0     1
# ...           ...               ...    ... .. .. ..  ..   ...   ...
# 4371          NaN               NaN      0  1  0  0   0     0     1
# 4372          NaN               NaN      0  1  0  0   0     0     1
# 4373          NaN               NaN      0  0  0  0   1     0     1
# 4374          NaN               NaN      0  1  0  5   0     1     5
# 4375     J-ZS9553               NaN     20  0  0  0   1     0     1
#
# [4376 rows x 16 columns]

# %% [markdown]
# > **data/output/trees/iid/tree_output_iid.txt**: this file contains information for the whole path until the most derived Y-haplogroup assigned to an individual. Every line is divided as follows:
# > 1. **[Haplogroup Name]**: first item in line indicating the name of the Y-haplogroup.
# > 2. **Level**: number of steps from Root until current node.
# > 3. **DER in branch**: number of SNPs with derived state in current node (marked in grey the total of SNPs for the node).
# > 4. **ANC in branch**: number of SNPs with ancestral state in current node (marked in grey the total of SNPs for the node).
# > 5. **DER in par.**: number of SNPs with derived state from Root until current node (marked in gray the total of SNPs for parent nodes).
# > 6. **ANC in par.**: number of SNPs with ancestral state from Root until current node (marked in gray the total of SNPs for parent nodes).
#
# **NOTE**: if no SNPs for a Y-haplogroup have been covered, the total count is considered 0 and it is labeled as "Not Found".

# %%
with open ("data/output/trees/PTN227/tree_output_PTN227.txt", "r") as file:
    for line in file.readlines():
        print(line,end="")
# Out:
# Tree created for sample PTN227, with most derived Y-haplogroup: E-BY153750
# |
# |___> nan, Level: 0, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#   |
#   |___> A-PR2921, Level: 1, DER in branch: 1/1, ANC in branch: 0/1, DER in par.: 0/0, ANC in par.: 0/0
#     |
#     |___> A-L1090, Level: 2, DER in branch: 42/42, ANC in branch: 0/42, DER in par.: 1/1, ANC in par.: 0/1
#       |
#       |___> A-V168, Level: 3, DER in branch: 11/11, ANC in branch: 0/11, DER in par.: 43/43, ANC in par.: 0/43
#         |
#         |___> A-V221, Level: 4, DER in branch: 1/1, ANC in branch: 0/1, DER in par.: 54/54, ANC in par.: 0/54
#           |
#           |___> BT-M42, Level: 5, DER in branch: 1/1, ANC in branch: 0/1, DER in par.: 55/55, ANC in par.: 0/55
#             |
#             |___> CT-M168, Level: 6, DER in branch: 4/4, ANC in branch: 0/4, DER in par.: 56/56, ANC in par.: 0/56
#               |
#               |___> DE-M145, Level: 7, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#                 |
#                 |___> E-M96, Level: 8, DER in branch: 2/2, ANC in branch: 0/2, DER in par.: 60/60, ANC in par.: 0/60
#                   |
#                   |___> E-PF1764, Level: 9, DER in branch: 1/1, ANC in branch: 0/1, DER in par.: 62/62, ANC in par.: 0/62
#                     |
#                     |___> E-P147, Level: 10, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#                       |
#                       |___> E-P177, Level: 11, DER in branch: 2/2, ANC in branch: 0/2, DER in par.: 63/63, ANC in par.: 0/63
#                         |
#                         |___> E-P2, Level: 12, DER in branch: 0/1, ANC in branch: 1/1, DER in par.: 65/65, ANC in par.: 0/65
#                           |
#                           |___> E-PAGES00040, Level: 13, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#                             |
#                             |___> E-M35, Level: 14, DER in branch: 26/26, ANC in branch: 0/26, DER in par.: 65/66, ANC in par.: 1/66
#                               |
#                               |___> E-V68, Level: 15, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#                                 |
#                                 |___> E-M78, Level: 16, DER in branch: 16/16, ANC in branch: 0/16, DER in par.: 91/92, ANC in par.: 1/92
#                                   |
#                                   |___> E-PF2179, Level: 17, DER in branch: 2/2, ANC in branch: 0/2, DER in par.: 107/108, ANC in par.: 1/108
#                                     |
#                                     |___> E-Z1919, Level: 18, DER in branch: 5/5, ANC in branch: 0/5, DER in par.: 109/110, ANC in par.: 1/110
#                                       |
#                                       |___> E-L618, Level: 19, DER in branch: 8/8, ANC in branch: 0/8, DER in par.: 114/115, ANC in par.: 1/115
#                                         |
#                                         |___> E-CTS1975, Level: 20, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#                                           |
#                                           |___> E-V13, Level: 21, DER in branch: 9/9, ANC in branch: 0/9, DER in par.: 122/123, ANC in par.: 1/123
#                                             |
#                                             |___> E-Z1057, Level: 22, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#                                               |
#                                               |___> E-PH1246, Level: 23, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#                                                 |
#                                                 |___> E-BY14151, Level: 24, DER in branch: 0, Not Found, ANC in branch: 0, Not Found, DER in par.: 0, Not Found, ANC in par.: 0, Not Found
#                                                   |
#                                                   |___> E-BY34236, Level: 25, DER in branch: 1/1, ANC in branch: 0/1, DER in par.: 131/132, ANC in par.: 1/132
#                                                     |
#                                                     |___> E-BY153750, Level: 26, DER in branch: 1/1, ANC in branch: 0/1, DER in par.: 132/133, ANC in par.: 1/133

# %% [markdown]
# > **data/output/paths.txt**: this file contains similar information to the tree created above, with the difference that every line is made by the sample ID and the Y-haplogroup names sorted from Root until most derived haplogroup.

# %%
with open ("data/output/paths.txt", "r") as file:
    for line in file.readlines():
        print(line,end="")
# Out:
# PTN227: nan,A-PR2921,A-L1090,A-V168,A-V221,BT-M42,CT-M168,DE-M145,E-M96,E-PF1764,E-P147,E-P177,E-P2,E-PAGES00040,E-M35,E-V68,E-M78,E-PF2179,E-Z1919,E-L618,E-CTS1975,E-V13,E-Z1057,E-PH1246,E-BY14151,E-BY34236,E-BY153750

# %% [markdown]
# ***

# %% [markdown]
# ## Running **y_call** on the whole set of samples ##

# %%
# Run function for the software: y_call.
y_call(bam_list=args.bam_list, initial=args.index_i, final=args.index_f,
       base_qual=args.base_qual, map_qual=args.map_qual, path_snps=args.snps,
       reference_genome=args.rg, create_network=args.create_network,
       width=args.width, height=args.height, transitions=args.transitions,
       tree=args.haplogr_tree, translation=args.translation, mm=args.mismatches,
       branches=args.branches, ex_limit=args.ex_limit)
